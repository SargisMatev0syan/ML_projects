# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_test = pd.read_csv('test.csv')
df_train = pd.read_csv('train.csv')

# %%
df_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_train = df_train.drop('Name', axis=1)

# %%
df_train['Ticket'].value_counts()
# Out:
# Ticket
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: count, Length: 681, dtype: int64

# %%
df_train.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df_train
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df_train['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
df_train['Sex'] = df_train['Sex'].replace(to_replace='male', value=0)
df_train['Sex'] = df_train['Sex'].replace(to_replace='female',value=1)
df_test['Sex'] = df_train['Sex'].replace(to_replace='male',value=0)
df_test['Sex'] = df_train['Sex'].replace(to_replace='female',value=1)

# %%
df_train.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
len(df_train)
# Out:
# 891

# %%
df_train = df_train.drop('Cabin', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df_train = df_train.drop('Cabin', axis=1)
#
# File ~\Desktop\for_ml\venv\Lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
#    5354         errors=errors,
#    5355     )
#
# ...

# %%
df_train
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0              1         0       3    0  22.0      1      0         A/5 21171
# 1              2         1       1    1  38.0      1      0          PC 17599
# 2              3         1       3    1  26.0      0      0  STON/O2. 3101282
# 3              4         1       1    1  35.0      1      0            113803
# 4              5         0       3    0  35.0      0      0            373450
# ..           ...       ...     ...  ...   ...    ...    ...               ...
# 886          887         0       2    0  27.0      0      0            211536
# 887          888         1       1    1  19.0      0      0            112053
# 888          889         0       3    1   NaN      1      2        W./C. 6607
# 889          890         1       1    0  26.0      0      0            111369
# 890          891         0       3    0  32.0      0      0            370376
#
#         Fare Embarked
# ...

# %%
df_test =df_test.drop('Cabin', axis=1)

# %%
df_test
# Out:
#      PassengerId  Pclass                                          Name  Sex  \
# 0            892       3                              Kelly, Mr. James    0
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)    1
# 2            894       2                     Myles, Mr. Thomas Francis    1
# 3            895       3                              Wirz, Mr. Albert    1
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0
# ..           ...     ...                                           ...  ...
# 413         1305       3                            Spector, Mr. Woolf    0
# 414         1306       1                  Oliva y Ocana, Dona. Fermina    0
# 415         1307       3                  Saether, Mr. Simon Sivertsen    1
# 416         1308       3                           Ware, Mr. Frederick    1
# 417         1309       3                      Peter, Master. Michael J    1
#
# ...

# %%
df_test = df_test.drop('Name', axis=1)

# %%
df_test
# Out:
#      PassengerId  Pclass  Sex   Age  SibSp  Parch              Ticket  \
# 0            892       3    0  34.5      0      0              330911
# 1            893       3    1  47.0      1      0              363272
# 2            894       2    1  62.0      0      0              240276
# 3            895       3    1  27.0      0      0              315154
# 4            896       3    0  22.0      1      1             3101298
# ..           ...     ...  ...   ...    ...    ...                 ...
# 413         1305       3    0   NaN      0      0           A.5. 3236
# 414         1306       1    0  39.0      0      0            PC 17758
# 415         1307       3    1  38.5      0      0  SOTON/O.Q. 3101262
# 416         1308       3    1   NaN      0      0              359309
# 417         1309       3    1   NaN      1      1                2668
#
#          Fare Embarked
# 0      7.8292        Q
# 1      7.0000        S
# 2      9.6875        Q
# 3      8.6625        S
# ...

# %%
df_train['Embarked'] = df_train['Embarked'].fillna('Q')

# %%
df_train['Embarked'] = df_train['Embarked'].replace('Q', 0)
df_train['Embarked'] = df_train['Embarked'].replace('S', 1)
df_train['Embarked'] = df_train['Embarked'].replace('C', 2)
df_test['Embarked'] = df_test['Embarked'].replace('Q', 0)
df_test['Embarked'] = df_test['Embarked'].replace('S', 1)
df_test['Embarked'] = df_test['Embarked'].replace('C', 2)

# %%
df_train
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0              1         0       3    0  22.0      1      0         A/5 21171
# 1              2         1       1    1  38.0      1      0          PC 17599
# 2              3         1       3    1  26.0      0      0  STON/O2. 3101282
# 3              4         1       1    1  35.0      1      0            113803
# 4              5         0       3    0  35.0      0      0            373450
# ..           ...       ...     ...  ...   ...    ...    ...               ...
# 886          887         0       2    0  27.0      0      0            211536
# 887          888         1       1    1  19.0      0      0            112053
# 888          889         0       3    1   NaN      1      2        W./C. 6607
# 889          890         1       1    0  26.0      0      0            111369
# 890          891         0       3    0  32.0      0      0            370376
#
#         Fare  Embarked
# ...

# %%
df_test.value_counts()
# Out:
# PassengerId  Pclass  Sex  Age   SibSp  Parch  Ticket              Fare     Embarked
# 892          3       0    34.5  0      0      330911              7.8292   Q           1
# 1186         3       0    36.0  0      0      345771              9.5000   S           1
# 1183         3       1    30.0  0      0      382650              6.9500   Q           1
# 1179         1       0    24.0  1      0      21228               82.2667  S           1
# 1177         3       0    36.0  0      0      A/5 21175           7.2500   S           1
#                                                                                       ..
# 1029         2       0    26.0  0      0      248659              13.0000  S           1
# 1028         3       1    26.5  0      0      2656                7.2250   C           1
# 1027         3       0    24.0  0      0      350409              7.8542   S           1
# 1026         3       0    43.0  0      0      349226              7.8958   S           1
# ...

# %%
df_test.isna().sum()
# Out:
# PassengerId     0
# Pclass          0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Ticket          0
# Fare            1
# Embarked        0
# dtype: int64

# %%
df_train.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %%
df_train['Age'] = df_train['Age'].interpolate()
df_test['Age'] = df_test['Age'].interpolate()

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    int64
#  4   Age          891 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Fare         891 non-null    float64
#  8   Embarked     891 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 62.8 KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Sex          418 non-null    int64
#  3   Age          332 non-null    float64
#  4   SibSp        418 non-null    int64
#  5   Parch        418 non-null    int64
#  6   Ticket       418 non-null    object
#  7   Fare         417 non-null    float64
#  8   Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 29.5+ KB

# %%
df_train =df_train.drop('Ticket', axis=1)

# %%
df_test
# Out:
#      PassengerId  Pclass  Sex   Age  SibSp  Parch              Ticket  \
# 0            892       3    0  34.5      0      0              330911
# 1            893       3    1  47.0      1      0              363272
# 2            894       2    1  62.0      0      0              240276
# 3            895       3    1  27.0      0      0              315154
# 4            896       3    0  22.0      1      1             3101298
# ..           ...     ...  ...   ...    ...    ...                 ...
# 413         1305       3    0  33.5      0      0           A.5. 3236
# 414         1306       1    0  39.0      0      0            PC 17758
# 415         1307       3    1  38.5      0      0  SOTON/O.Q. 3101262
# 416         1308       3    1  38.5      0      0              359309
# 417         1309       3    1  38.5      1      1                2668
#
#          Fare  Embarked
# 0      7.8292         0
# 1      7.0000         1
# 2      9.6875         0
# 3      8.6625         1
# ...

# %%
df_test['Fare'] = df_test['Fare'].interpolate()
# Out:
# C:\Users\Sargis Matevosyan\AppData\Local\Temp\ipykernel_16632\2983431430.py:1: FutureWarning: Series.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_test['Fare'] = df_test['Fare'].interpolate()

# %%
df_train
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0              1         0       3    0  22.0      1      0   7.2500         1
# 1              2         1       1    1  38.0      1      0  71.2833         2
# 2              3         1       3    1  26.0      0      0   7.9250         1
# 3              4         1       1    1  35.0      1      0  53.1000         1
# 4              5         0       3    0  35.0      0      0   8.0500         1
# ..           ...       ...     ...  ...   ...    ...    ...      ...       ...
# 886          887         0       2    0  27.0      0      0  13.0000         1
# 887          888         1       1    1  19.0      0      0  30.0000         1
# 888          889         0       3    1  22.5      1      2  23.4500         1
# 889          890         1       1    0  26.0      0      0  30.0000         2
# 890          891         0       3    0  32.0      0      0   7.7500         0
#
# [891 rows x 9 columns]

# %%
df_test
# Out:
#      PassengerId  Pclass  Sex   Age  SibSp  Parch              Ticket  \
# 0            892       3    0  34.5      0      0              330911
# 1            893       3    1  47.0      1      0              363272
# 2            894       2    1  62.0      0      0              240276
# 3            895       3    1  27.0      0      0              315154
# 4            896       3    0  22.0      1      1             3101298
# ..           ...     ...  ...   ...    ...    ...                 ...
# 413         1305       3    0  33.5      0      0           A.5. 3236
# 414         1306       1    0  39.0      0      0            PC 17758
# 415         1307       3    1  38.5      0      0  SOTON/O.Q. 3101262
# 416         1308       3    1  38.5      0      0              359309
# 417         1309       3    1  38.5      1      1                2668
#
#                                                   Fare  Embarked
# ...

# %%
df_test
# Out:
#      PassengerId  Pclass  Sex   Age  SibSp  Parch              Ticket  \
# 0            892       3    0  34.5      0      0              330911
# 1            893       3    1  47.0      1      0              363272
# 2            894       2    1  62.0      0      0              240276
# 3            895       3    1  27.0      0      0              315154
# 4            896       3    0  22.0      1      1             3101298
# ..           ...     ...  ...   ...    ...    ...                 ...
# 413         1305       3    0  33.5      0      0           A.5. 3236
# 414         1306       1    0  39.0      0      0            PC 17758
# 415         1307       3    1  38.5      0      0  SOTON/O.Q. 3101262
# 416         1308       3    1  38.5      0      0              359309
# 417         1309       3    1  38.5      1      1                2668
#
#                                                   Fare  Embarked
# ...

# %%
df_test.isna().sum()
# Out:
# PassengerId    0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df_test =df_test.drop('Ticket', axis=1)

# %%
X_train = df_train.drop('Survived', axis = 1)
y_train = df_train['Survived']
X_test = df_test

# %%
y_train
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model = KNeighborsClassifier()

# %%
from sklearn.model_selection import GridSearchCV

# %%
full_model = GridSearchCV(model, param_grid={'n_neighbors':list(range(1,50,2))}, cv=5, verbose=2)

# %%
full_model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV] END ......................................n_neighbors=1; total time=   0.0s
# [CV] END ......................................n_neighbors=1; total time=   0.0s
# [CV] END ......................................n_neighbors=1; total time=   0.0s
# [CV] END ......................................n_neighbors=1; total time=   0.0s
# [CV] END ......................................n_neighbors=1; total time=   0.0s
# [CV] END ......................................n_neighbors=3; total time=   0.0s
# [CV] END ......................................n_neighbors=3; total time=   0.0s
# [CV] END ......................................n_neighbors=3; total time=   0.0s
# [CV] END ......................................n_neighbors=3; total time=   0.0s
# [CV] END ......................................n_neighbors=3; total time=   0.0s
# [CV] END ......................................n_neighbors=5; total time=   0.0s
# ...

# %%
full_model.best_params_
# Out:
# {'n_neighbors': 45}

# %%
y_pred = full_model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16632\495303579.py in ?()
# ----> 1 y_pred = full_model.predict(X_test)
#
# ~\Desktop\for_ml\venv\Lib\site-packages\sklearn\model_selection\_search.py in ?(self, X)
#     515             The predicted labels or values for `X` based on the estimator with
#     516             the best found parameters.
#     517         """
#     518         check_is_fitted(self)
# --> 519         return self.best_estimator_.predict(X)
#
# ~\Desktop\for_ml\venv\Lib\site-packages\sklearn\neighbors\_classification.py in ?(self, X)
#     262                     )
#     263                 return self.classes_[np.argmax(probabilities, axis=1)]
#     264             # In that case, we do not need the distances to perform
#     265             # the weighting so we do not compute them.
# ...

# %%
y_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 y_pred
#
# NameError: name 'y_pred' is not defined

# %%
data_pred = X_test['PassengerId']

# %%
data_pred['Survived'] = y_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 data_pred['Survived'] = y_pred
#
# NameError: name 'y_pred' is not defined

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
