# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('GOOG.csv')

# %%
data
# Out:
#             Date        Open        High         Low       Close   Adj Close
# 0     2004-08-19    2.490664    2.591785    2.390042    2.499133    2.499133  \
# 1     2004-08-20    2.515820    2.716817    2.503118    2.697639    2.697639
# 2     2004-08-23    2.758411    2.826406    2.716070    2.724787    2.724787
# 3     2004-08-24    2.770615    2.779581    2.579581    2.611960    2.611960
# 4     2004-08-25    2.614201    2.689918    2.587302    2.640104    2.640104
# ...          ...         ...         ...         ...         ...         ...
# 4837  2023-11-06  130.220001  131.559998  129.929993  131.449997  131.449997
# 4838  2023-11-07  131.979996  133.279999  131.139999  132.399994  132.399994
# 4839  2023-11-08  132.360001  133.539993  132.160004  133.259995  133.259995
# 4840  2023-11-09  133.360001  133.960007  131.509995  131.690002  131.690002
# 4841  2023-11-10  131.529999  134.270004  130.869995  134.059998  134.059998
#
#          Volume
# 0     897427216
# ...

# %%
var_list = []
n = 2000
summ = 0
df = pd.DataFrame(columns=[f't-{i - 1}' for i in range(1, 1001)])
for i in range(1, 1001):
    df_t = data['Close'][-i:(-n - i) :-1]
    df[f't-{i - 1}'] = df_t.values
    
#df = pd.DataFrame(columns=[f't-{i - 1}' for i in range(1, 1001)]): This line creates a new pandas DataFrame named df.
#The DataFrame is initialized with 1000 columns labeled as 't-0', 't-1', ..., 't-999'.
#These column names are generated using a list comprehension where each column name is formatted as 't-' followed by i - 1 for i ranging from 1 to 1000.

# In summary, this code creates a DataFrame df with 1000 columns ('t-0' to 't-999'). Each column in the DataFrame contains a subset of values
# extracted in reverse order from the 'Close' column of a pandas Series data['Close'], where each subset starts from a position calculated based on
# the loop index i. The result is a DataFrame structured for further analysis or processing based on these extracted historical values from the 'Close' column.

# %%
df
# Out:
#              t-0         t-1         t-2         t-3         t-4         t-5
# 0     134.059998  131.690002  133.259995  132.399994  131.449997  130.369995  \
# 1     131.690002  133.259995  132.399994  131.449997  130.369995  128.580002
# 2     133.259995  132.399994  131.449997  130.369995  128.580002  127.570000
# 3     132.399994  131.449997  130.369995  128.580002  127.570000  125.300003
# 4     131.449997  130.369995  128.580002  127.570000  125.300003  125.750000
# ...          ...         ...         ...         ...         ...         ...
# 1995   38.118500   38.162498   38.340500   37.626999   38.118999   38.352001
# 1996   38.162498   38.340500   37.626999   38.118999   38.352001   37.130001
# 1997   38.340500   37.626999   38.118999   38.352001   37.130001   37.513000
# 1998   37.626999   38.118999   38.352001   37.130001   37.513000   37.407501
# 1999   38.118999   38.352001   37.130001   37.513000   37.407501   37.414001
#
# ...

# %%
var_list = np.var(df)

# %%
plt.plot(var_list[120:140])
plt.xticks(rotation=90)
plt.show()

# %%
data[-1:-128:-1]['Date']
# Out:
# 4841    2023-11-10
# 4840    2023-11-09
# 4839    2023-11-08
# 4838    2023-11-07
# 4837    2023-11-06
#            ...
# 4719    2023-05-18
# 4718    2023-05-17
# 4717    2023-05-16
# 4716    2023-05-15
# 4715    2023-05-12
# Name: Date, Length: 127, dtype: object

# %%
df['t-128']
# Out:
# 0       112.279999
# 1       107.940002
# 2       108.239998
# 3       106.214996
# 4       105.209999
#            ...
# 1995     26.341499
# 1996     26.666500
# 1997     26.834999
# 1998     27.015499
# 1999     26.959000
# Name: t-128, Length: 2000, dtype: float64

# %%
data[['Open', 'High', 'Low', 'Close','Adj Close']].corr()
# Out:
#                Open      High       Low     Close  Adj Close
# Open       1.000000  0.999902  0.999895  0.999772   0.999772
# High       0.999902  1.000000  0.999874  0.999893   0.999893
# Low        0.999895  0.999874  1.000000  0.999903   0.999903
# Close      0.999772  0.999893  0.999903  1.000000   1.000000
# Adj Close  0.999772  0.999893  0.999903  1.000000   1.000000

# %%
df
# Out:
#              t-0         t-1         t-2         t-3         t-4         t-5
# 0     134.059998  131.690002  133.259995  132.399994  131.449997  130.369995  \
# 1     131.690002  133.259995  132.399994  131.449997  130.369995  128.580002
# 2     133.259995  132.399994  131.449997  130.369995  128.580002  127.570000
# 3     132.399994  131.449997  130.369995  128.580002  127.570000  125.300003
# 4     131.449997  130.369995  128.580002  127.570000  125.300003  125.750000
# ...          ...         ...         ...         ...         ...         ...
# 1995   38.118500   38.162498   38.340500   37.626999   38.118999   38.352001
# 1996   38.162498   38.340500   37.626999   38.118999   38.352001   37.130001
# 1997   38.340500   37.626999   38.118999   38.352001   37.130001   37.513000
# 1998   37.626999   38.118999   38.352001   37.130001   37.513000   37.407501
# 1999   38.118999   38.352001   37.130001   37.513000   37.407501   37.414001
#
# ...

# %%
var_list = []
n = len(data)
summ = 0
df = pd.DataFrame(columns=[f't-{i - 1}' for i in range(1, 1001)])
for i in range(1, 1001):
    df_t = data['Close'][-i::-1]
    df[f't-{i - 1}'] = df_t

# %%
new_df = df.reset_index().drop('index', axis=1)

# %%
new_df
# Out:
#              t-0         t-1         t-2         t-3         t-4       t-5
# 0     134.059998         NaN         NaN         NaN         NaN       NaN  \
# 1     131.690002  131.690002         NaN         NaN         NaN       NaN
# 2     133.259995  133.259995  133.259995         NaN         NaN       NaN
# 3     132.399994  132.399994  132.399994  132.399994         NaN       NaN
# 4     131.449997  131.449997  131.449997  131.449997  131.449997       NaN
# ...          ...         ...         ...         ...         ...       ...
# 4837    2.640104    2.640104    2.640104    2.640104    2.640104  2.640104
# 4838    2.611960    2.611960    2.611960    2.611960    2.611960  2.611960
# 4839    2.724787    2.724787    2.724787    2.724787    2.724787  2.724787
# 4840    2.697639    2.697639    2.697639    2.697639    2.697639  2.697639
# 4841    2.499133    2.499133    2.499133    2.499133    2.499133  2.499133
#
# ...

# %%
len(new_df['t-1'].dropna())
# Out:
# 4841

# %%
var_list = []
for i in new_df.columns:
    var_list.append(np.var(new_df[i].dropna()))

# %%
plt.plot(var_list)

# %%
n = 3000
summ = 0
df = pd.DataFrame(columns=[f't-{i - 1}' for i in range(1, 1001)])
for i in range(1, 1001):
    df_t = data['Close'][-i:(-n - i) :-1]
    df[f't-{i - 1}'] = df_t.values

# %%
plt.figure(figsize=(10, 20), dpi=400)
plt.plot(np.var(df))
plt.ylim(1300, 1320)
plt.xlim(120, 240)
plt.savefig('new.jpg')
# plt.xlim(0, 200)
